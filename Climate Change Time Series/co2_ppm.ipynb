# %%
import pandas
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
data = pandas.read_csv('co2_ppm.csv')
plt.scatter(data['Year'], data['Co2_PPM'])
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
model = LinearRegression()
model.fit(data[['Year']], data[['Co2_PPM']])
# Out:
# LinearRegression()

# %%
# importing libraries
import seaborn as sb
  
# use lmplot
sb.lmplot(x = "Year",
            y = "Co2_PPM", 
            ci = None,
            data = data)

# %%
import numpy as np

# %%
X = data.iloc[:, 0:1].values
y = data.iloc[:, 1].values

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
  
poly = PolynomialFeatures(degree = 4)
  
poly.fit(data[['Year']], data[['Co2_PPM']])
# Out:
# PolynomialFeatures(degree=4)

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
  
poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(X)
  
poly.fit(X_poly, y)
lin2 = LinearRegression()
lin2.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
# Visualising the Polynomial Regression results
plt.scatter(X, y, color = 'blue')
  
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red')
plt.title('Polynomial Regression')
plt.xlabel('Year')
plt.ylabel('co2 per PPM')
  
plt.show()

# %%
pred2 = 2023
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([421.12709767])

# %%
pred2 = 2024
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([423.7671276])

# %%
pred2 = 2025
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([426.44415326])

# %%
pred2 = 2026
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([429.15848763])

# %%
pred2 = 2027
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([431.91044412])

# %%
pred2 = 2028
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([434.70033653])

# %%
pred2 = 2029
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([437.52847909])

# %%
pred2 = 2030
pred2array = np.array([[pred2]])
lin2.predict(poly.fit_transform(pred2array))
# Out:
# array([440.39518644])
