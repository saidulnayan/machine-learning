# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
import tensorflow as tf
import numpy as np
import cv2
from keras.utils import np_utils
from glob import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
from keras.models import load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger
from sklearn.metrics import classification_report, accuracy_score
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import splitfolders
import pandas as pd
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Lenovo\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Lenovo\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
input_folder = 'C:/Users/Lenovo/Downloads/Augmented_dataset/Augmented__dataset'
#ration of split is 70%, 20% and 10%
splitfolders.ratio(input_folder, output="H:/Shortcuts/Research paper/flowerNET/flower", 
                   seed=42, ratio=(.7, .2, .1), 
                   group_prefix=None)
# Out:
# Copying files: 4342 files [01:52, 38.46 files/s]

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

train_path = 'H:/Shortcuts/Research paper/flowerNET/flower/train'
valid_path = 'H:/Shortcuts/Research paper/flowerNET/flower/val'
test_path = 'H:/Shortcuts/Research paper/flowerNET/flower/test'

# %%
  # useful for getting number of classes
folders = glob('H:/Shortcuts/Research paper/flowerNET/flower/train/*')
len(folders)
# Out:
# 3

# %%
IMAGE_SIZE + [3]
# Out:
# [224, 224, 3]

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3,3), activation='relu', input_shape=IMAGE_SIZE + [3]))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, kernel_size = (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, kernel_size = (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, kernel_size = (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, kernel_size = (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, kernel_size = (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(len(folders), activation = 'softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 64)        36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 171,459
# Trainable params: 171,459
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
IMAGE_SIZE=224
BATCH_SIZE=32

#pre=processing

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=0,
                                   vertical_flip=False,
                                   horizontal_flip = True)

val_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (IMAGE_SIZE, IMAGE_SIZE),
                                                 batch_size = BATCH_SIZE,
                                                 class_mode = 'categorical')

validation_set = val_datagen.flow_from_directory(valid_path,
                                            target_size = (IMAGE_SIZE, IMAGE_SIZE),
                                            batch_size = BATCH_SIZE,
                                            class_mode = 'categorical')
# Out:
# Found 3037 images belonging to 3 classes.
# Found 867 images belonging to 3 classes.

# %%
labels = (training_set.class_indices)
print(labels)
# Out:
# {'Black Spot': 0, 'Downy mildew': 1, 'Fresh Leaf': 2}

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
r = model.fit(
  training_set,
  validation_data=validation_set,
  epochs=50,
  steps_per_epoch=len(training_set),
  validation_steps=len(validation_set))
# Out:
# Epoch 1/50
# 95/95 [==============================] - 310s 3s/step - loss: 0.7000 - accuracy: 0.5943 - val_loss: 0.5396 - val_accuracy: 0.6574
# Epoch 2/50
# 95/95 [==============================] - 281s 3s/step - loss: 0.5372 - accuracy: 0.6852 - val_loss: 0.5131 - val_accuracy: 0.7324
# Epoch 3/50
# 95/95 [==============================] - 413s 4s/step - loss: 0.5178 - accuracy: 0.7060 - val_loss: 0.4870 - val_accuracy: 0.7232
# Epoch 4/50
# 95/95 [==============================] - 336s 4s/step - loss: 0.4847 - accuracy: 0.7435 - val_loss: 0.4726 - val_accuracy: 0.7416
# Epoch 5/50
# 95/95 [==============================] - 308s 3s/step - loss: 0.4896 - accuracy: 0.7438 - val_loss: 0.5185 - val_accuracy: 0.7601
# Epoch 6/50
# 95/95 [==============================] - 358s 4s/step - loss: 0.4761 - accuracy: 0.7593 - val_loss: 0.4781 - val_accuracy: 0.7751
# Epoch 7/50
# 95/95 [==============================] - 355s 4s/step - loss: 0.4580 - accuracy: 0.7590 - val_loss: 0.4520 - val_accuracy: 0.7866
# Epoch 8/50
# 95/95 [==============================] - 257s 3s/step - loss: 0.4535 - accuracy: 0.7820 - val_loss: 0.4359 - val_accuracy: 0.7958
# Epoch 9/50
# 95/95 [==============================] - 334s 4s/step - loss: 0.4459 - accuracy: 0.7771 - val_loss: 0.4361 - val_accuracy: 0.7716
# Epoch 10/50
# 95/95 [==============================] - 307s 3s/step - loss: 0.4044 - accuracy: 0.8077 - val_loss: 0.3985 - val_accuracy: 0.8085
# Epoch 11/50
# 95/95 [==============================] - 281s 3s/step - loss: 0.3986 - accuracy: 0.8074 - val_loss: 0.3996 - val_accuracy: 0.8212
# Epoch 12/50
# 95/95 [==============================] - 303s 3s/step - loss: 0.2534 - accuracy: 0.9029 - val_loss: 0.2322 - val_accuracy: 0.9158
# Epoch 13/50
# 95/95 [==============================] - 286s 3s/step - loss: 0.1971 - accuracy: 0.9312 - val_loss: 0.1976 - val_accuracy: 0.9204
# Epoch 14/50
# 95/95 [==============================] - 300s 3s/step - loss: 0.1404 - accuracy: 0.9539 - val_loss: 0.1667 - val_accuracy: 0.9354
# Epoch 15/50
# 95/95 [==============================] - 277s 3s/step - loss: 0.1228 - accuracy: 0.9569 - val_loss: 0.1154 - val_accuracy: 0.9608
# Epoch 16/50
# 95/95 [==============================] - 299s 3s/step - loss: 0.1171 - accuracy: 0.9598 - val_loss: 0.1656 - val_accuracy: 0.9412
# Epoch 17/50
# 95/95 [==============================] - 291s 3s/step - loss: 0.0983 - accuracy: 0.9671 - val_loss: 0.1467 - val_accuracy: 0.9481
# Epoch 18/50
# 95/95 [==============================] - 292s 3s/step - loss: 0.1026 - accuracy: 0.9654 - val_loss: 0.1554 - val_accuracy: 0.9596
# Epoch 19/50
# 95/95 [==============================] - 251s 3s/step - loss: 0.1079 - accuracy: 0.9644 - val_loss: 0.1196 - val_accuracy: 0.9642
# Epoch 20/50
# 95/95 [==============================] - 223s 2s/step - loss: 0.0818 - accuracy: 0.9697 - val_loss: 0.1005 - val_accuracy: 0.9700
# Epoch 21/50
# 95/95 [==============================] - 219s 2s/step - loss: 0.0696 - accuracy: 0.9766 - val_loss: 0.1067 - val_accuracy: 0.9642
# Epoch 22/50
# 95/95 [==============================] - 222s 2s/step - loss: 0.0642 - accuracy: 0.9766 - val_loss: 0.0891 - val_accuracy: 0.9654
# Epoch 23/50
# 95/95 [==============================] - 223s 2s/step - loss: 0.0627 - accuracy: 0.9812 - val_loss: 0.1375 - val_accuracy: 0.9516
# Epoch 24/50
# 95/95 [==============================] - 219s 2s/step - loss: 0.0792 - accuracy: 0.9766 - val_loss: 0.1456 - val_accuracy: 0.9516
# Epoch 25/50
# 95/95 [==============================] - 218s 2s/step - loss: 0.0696 - accuracy: 0.9786 - val_loss: 0.1121 - val_accuracy: 0.9700
# Epoch 26/50
# 95/95 [==============================] - 219s 2s/step - loss: 0.0663 - accuracy: 0.9789 - val_loss: 0.0953 - val_accuracy: 0.9700
# Epoch 27/50
# 95/95 [==============================] - 218s 2s/step - loss: 0.0389 - accuracy: 0.9875 - val_loss: 0.1131 - val_accuracy: 0.9746
# Epoch 28/50
# 95/95 [==============================] - 221s 2s/step - loss: 0.0643 - accuracy: 0.9783 - val_loss: 0.1015 - val_accuracy: 0.9631
# Epoch 29/50
# 95/95 [==============================] - 220s 2s/step - loss: 0.0469 - accuracy: 0.9868 - val_loss: 0.1761 - val_accuracy: 0.9504
# Epoch 30/50
# 95/95 [==============================] - 283s 3s/step - loss: 0.0475 - accuracy: 0.9825 - val_loss: 0.1312 - val_accuracy: 0.9596
# Epoch 31/50
# 95/95 [==============================] - 269s 3s/step - loss: 0.0606 - accuracy: 0.9799 - val_loss: 0.1259 - val_accuracy: 0.9735
# Epoch 32/50
# 95/95 [==============================] - 262s 3s/step - loss: 0.0638 - accuracy: 0.9740 - val_loss: 0.1258 - val_accuracy: 0.9596
# Epoch 33/50
# 95/95 [==============================] - 258s 3s/step - loss: 0.0545 - accuracy: 0.9822 - val_loss: 0.1054 - val_accuracy: 0.9723
# Epoch 34/50
# 95/95 [==============================] - 304s 3s/step - loss: 0.0415 - accuracy: 0.9888 - val_loss: 0.0864 - val_accuracy: 0.9735
# Epoch 35/50
# 95/95 [==============================] - 360s 4s/step - loss: 0.0219 - accuracy: 0.9928 - val_loss: 0.0834 - val_accuracy: 0.9735
# Epoch 36/50
# 95/95 [==============================] - 332s 3s/step - loss: 0.0324 - accuracy: 0.9888 - val_loss: 0.1220 - val_accuracy: 0.9758
# Epoch 37/50
# 95/95 [==============================] - 21284s 226s/step - loss: 0.0311 - accuracy: 0.9911 - val_loss: 0.2110 - val_accuracy: 0.9319
# Epoch 38/50
# 95/95 [==============================] - 367s 4s/step - loss: 0.0656 - accuracy: 0.9809 - val_loss: 0.1548 - val_accuracy: 0.9596
# Epoch 39/50
# 95/95 [==============================] - 278s 3s/step - loss: 0.0277 - accuracy: 0.9911 - val_loss: 0.1136 - val_accuracy: 0.9689
# Epoch 40/50
# 95/95 [==============================] - 381s 4s/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.1160 - val_accuracy: 0.9677
# Epoch 41/50
# 95/95 [==============================] - 371s 4s/step - loss: 0.0173 - accuracy: 0.9960 - val_loss: 0.0919 - val_accuracy: 0.9746
# Epoch 42/50
# 95/95 [==============================] - 400s 4s/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.1648 - val_accuracy: 0.9654
# Epoch 43/50
# 95/95 [==============================] - 420s 4s/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.1906 - val_accuracy: 0.9539
# Epoch 44/50
# 95/95 [==============================] - 373s 4s/step - loss: 0.1013 - accuracy: 0.9704 - val_loss: 0.1259 - val_accuracy: 0.9654
# Epoch 45/50
# 95/95 [==============================] - 354s 4s/step - loss: 0.0485 - accuracy: 0.9849 - val_loss: 0.1128 - val_accuracy: 0.9654
# Epoch 46/50
# 95/95 [==============================] - 394s 4s/step - loss: 0.0303 - accuracy: 0.9905 - val_loss: 0.1348 - val_accuracy: 0.9712
# Epoch 47/50
# 95/95 [==============================] - 353s 4s/step - loss: 0.0214 - accuracy: 0.9941 - val_loss: 0.1343 - val_accuracy: 0.9585
# Epoch 48/50
# 95/95 [==============================] - 341s 4s/step - loss: 0.0127 - accuracy: 0.9974 - val_loss: 0.1146 - val_accuracy: 0.9712
# Epoch 49/50
# 95/95 [==============================] - 307s 3s/step - loss: 0.0185 - accuracy: 0.9957 - val_loss: 0.1529 - val_accuracy: 0.9666
# Epoch 50/50
# 95/95 [==============================] - 235s 2s/step - loss: 0.0315 - accuracy: 0.9905 - val_loss: 0.1876 - val_accuracy: 0.9469

# %%
train_loss, train_acc = model.evaluate(training_set, steps=16)
val_loss, val_acc = model.evaluate(validation_set, steps=16)
print("Traning Loss and traing accurcy: ",train_loss, train_acc )
print("Validation Loss and Validation accurcy: ",val_loss, val_acc )
# Out:
# 16/16 [==============================] - 27s 2s/step - loss: 0.0449 - accuracy: 0.9863
# 16/16 [==============================] - 24s 1s/step - loss: 0.1957 - accuracy: 0.9434
# Traning Loss and traing accurcy:  0.04492385685443878 0.986328125
# Validation Loss and Validation accurcy:  0.19573146104812622 0.943359375

# %%
# loss
sns.set_theme()
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.savefig('H:/Shortcuts/Research paper/flowerNET/lcnn_loss.svg')
plt.savefig('H:/Shortcuts/Research paper/flowerNET/lcnn_loss')
plt.show()

# %%
# accuracies
sns.set_theme()
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()

plt.savefig('H:/Shortcuts/Research paper/flowerNET/lcnn_acc.svg')
plt.savefig('H:/Shortcuts/Research paper/flowerNET/acc_loss')
plt.show()

# %%
model.save("H:/Shortcuts/Research paper/flowerNET/lcnn.h5")

# %%
testing_set = tf.keras.preprocessing.image_dataset_from_directory(
    test_path,
    seed=123,
    shuffle=False,
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 438 files belonging to 3 classes.

# %%
class_names = testing_set.class_names
class_names
# Out:
# ['Black Spot', 'Downy mildew', 'Fresh Leaf']

# %%
# Extracting all test image and corrosponding labels from tesing image
test_label=[]
test_img=[]
for img, label in testing_set:
  #print(label.numpy())
  test_label.append(label.numpy())
  test_img.append(img.numpy())
print("Total batch of test label: ",len(test_label))
print("Total batch of test image: ",len(test_img))

###############################################################################################

# Extracting only all test image  from tesing image batch list
actual_img=[]
for i in range(len(test_img)):
  for i in test_img[i]:
    i = i*(1/255) # we have to rescale the test image as well to feed the model
    actual_img.append(i)

print("Total Number of image: ", len(actual_img))


# Extracting only all test image  labels from tesing image batch list
actual_label=[]
for i in range(len(test_label)):
  for i in test_label[i]:
    actual_label.append(class_names[i])
     
    

print("Total number of image label : ",len(actual_label))
# Out:
# Total batch of test label:  14
# Total batch of test image:  14
# Total Number of image:  438
# Total number of image label :  438

# %%
print(actual_label[27])
plt.imshow(actual_img[27])
# Out:
# Black Spot

# %%
# make prediction using loaded model
predicted_label=[]
for img in actual_img:
  img_array = tf.expand_dims(img, 0)
  predictions = model.predict(img_array)
  label= class_names[np.argmax(predictions)]
  
  predicted_label.append(label)
 
  

len(predicted_label)
# Out:
# 438

# %%
# Printing all evaluation matrix
print("Test accuracy: ",accuracy_score(actual_label, predicted_label))
print(classification_report(actual_label, predicted_label))
# Out:
# Test accuracy:  0.95662100456621
#               precision    recall  f1-score   support
#
#   Black Spot       0.96      0.94      0.95       145
# Downy mildew       0.93      0.99      0.96       149
#   Fresh Leaf       0.99      0.94      0.96       144
#
#     accuracy                           0.96       438
#    macro avg       0.96      0.96      0.96       438
# weighted avg       0.96      0.96      0.96       438

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(actual_label, predicted_label)
import seaborn as sns
ax= plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, linewidth=.5)
plt.plot()
plt.savefig("confussion_matrix_custome.h5.svg")

# %%
# No need to run the belo cells

# %%
reconstructed_model = load_model("H:/Shortcuts/Research paper/flowerNET/lcnn.h5")
